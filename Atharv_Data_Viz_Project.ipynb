# %% [markdown]
# #Atharv Pramod Jangam Data Visualization Final Project
# ##Is climate change real?
# ###let's find it out

# %%
#importing all the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##First let's look at the data of global land temprature change from 1900-2022

# %%
global_Land = pd.read_csv("/content/drive/MyDrive/Data viz project/1900-2022 (global land).csv")

# %%
global_Land.head(10)
# Out:
#    Year  Value
# 0  1900  -1.05
# 1  1901  -0.42
# 2  1902   0.17
# 3  1903  -0.19
# 4  1904  -0.88
# 5  1905  -0.30
# 6  1906  -0.25
# 7  1907  -0.66
# 8  1908  -0.32
# 9  1909  -0.95

# %%
global_Land = global_Land.rename(columns={'Value': 'Temperature'})
global_Land.head()
# Out:
#    Year  Temperature
# 0  1900        -1.05
# 1  1901        -0.42
# 2  1902         0.17
# 3  1903        -0.19
# 4  1904        -0.88

# %%
import plotly.express as px
fig = px.bar(global_Land, x='Year', y='Temperature', color='Temperature', 
             labels={ 'Temperature' : 'Temperature (°C)'
                 
             },
             title="Global Land Temperature Anomalie")
fig.show()

#saving in html 
fig.write_html("bar graph.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6764bd61-e38d-4d22-a41c-425affe1e6a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6764bd61-e38d-4d22-a41c-425affe1e6a4")) {                    Plotly.newPlot(                        "6764bd61-e38d-4d22-a41c-425affe1e6a4",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{x}<br>Temperature (\u00b0C)=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[-1.05,-0.42,0.17,-0.19,-0.88,-0.3,-0.25,-0.66,-0.32,-0.95,-0.16,-0.79,-0.42,-0.5,0.82,-0.3,-0.17,-0.52,-0.64,-0.61,-0.06,0.21,-0.66,-0.13,-0.51,-0.5,0.54,-0.5,0.07,-0.94,-0.6,-0.06,0.84,-0.57,-0.38,-0.55,-0.58,-0.49,0.18,0.18,-0.46,0.03,0.33,-0.38,0.8,-0.18,0.33,-0.3,0.62,0.49,-0.77,-0.59,0.3,0.2,-0.68,0.66,-0.41,-0.33,0.76,0.22,0.05,0.3,0.35,0.16,0.12,0.11,-0.16,-0.21,-0.35,-1.05,0.07,0.12,-0.89,0.28,-0.62,0.38,0.26,-0.49,0.16,-0.06,0.19,1.19,-0.13,0.88,0.37,0.31,0.76,0.48,0.81,0.2,0.56,0.69,0.99,0.68,0.48,1.04,0.19,0.52,0.72,1.0,0.51,0.75,1.4,1.33,0.95,1.08,0.69,1.96,0.21,1.05,1.01,0.6,0.63,1.02,1.14,1.46,1.67,1.63,1.16,1.63,2.07,1.32,1.47],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[1900,1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022],"xaxis":"x","y":[-1.05,-0.42,0.17,-0.19,-0.88,-0.3,-0.25,-0.66,-0.32,-0.95,-0.16,-0.79,-0.42,-0.5,0.82,-0.3,-0.17,-0.52,-0.64,-0.61,-0.06,0.21,-0.66,-0.13,-0.51,-0.5,0.54,-0.5,0.07,-0.94,-0.6,-0.06,0.84,-0.57,-0.38,-0.55,-0.58,-0.49,0.18,0.18,-0.46,0.03,0.33,-0.38,0.8,-0.18,0.33,-0.3,0.62,0.49,-0.77,-0.59,0.3,0.2,-0.68,0.66,-0.41,-0.33,0.76,0.22,0.05,0.3,0.35,0.16,0.12,0.11,-0.16,-0.21,-0.35,-1.05,0.07,0.12,-0.89,0.28,-0.62,0.38,0.26,-0.49,0.16,-0.06,0.19,1.19,-0.13,0.88,0.37,0.31,0.76,0.48,0.81,0.2,0.56,0.69,0.99,0.68,0.48,1.04,0.19,0.52,0.72,1.0,0.51,0.75,1.4,1.33,0.95,1.08,0.69,1.96,0.21,1.05,1.01,0.6,0.63,1.02,1.14,1.46,1.67,1.63,1.16,1.63,2.07,1.32,1.47],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"color ...

# %% [markdown]
# Data source = "https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/global/time-series"

# %% [markdown]
# From the Graph above we can clearly see the change in the global land temperature and say that the from year 1900-2022 there is a huge change in the temperature. The major change came in the year 1980 and it is still increasing.
#
# Now let's find out for specific country and what could be reason behind it.

# %% [markdown]
# ##Average temprature change is India

# %%
India_temp = pd.read_csv("/content/drive/MyDrive/Data viz project/month_seas_ann_min_temp_India_1901_2016 (1).csv")

# %%
India_temp.head()
# Out:
#    YEAR  ANNUAL
# 0  1901   19.51
# 1  1902   19.44
# 2  1903   19.25
# 3  1904   19.22
# 4  1905   19.03

# %%
fig = px.line( India_temp, x='YEAR', y='ANNUAL',
             labels={ 'YEAR' : 'Year',
                      'ANNUAL' : 'Annual Temperature (°C)'
                 },
             title="Annual Average Temperature of India")
fig.update_traces(line_color='red')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ba168586-f250-4cd6-92b0-6611ef4de46d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba168586-f250-4cd6-92b0-6611ef4de46d")) {                    Plotly.newPlot(                        "ba168586-f250-4cd6-92b0-6611ef4de46d",                        [{"hovertemplate":"Year=%{x}<br>Annual Temperature (\u00b0C)=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016],"xaxis":"x","y":[19.51,19.44,19.25,19.22,19.03,19.51,19.08,19.09,19.13,19.01,19.31,19.27,19.09,19.41,19.64,19.34,19.02,19.02,19.37,19.07,19.54,19.32,19.36,19.52,19.24,19.37,19.3,19.61,19.4,19.21,19.73,19.32,19.35,19.22,19.21,19.53,19.25,19.28,19.16,19.24,19.85,19.45,19.06,19.18,18.89,19.38,19.23,19.49,19.28,18.95,19.36,19.51,19.71,19.33,19.19,19.29,19.3,19.92,19.6,19.27,19.27,19.2,19.28,19.11,18.98,19.31,19.08,18.83,19.32,19.16,18.77,18.91,19.38,18.76,18.62,18.9,19.31,19.25,19.55,19.53,19.25,19.21,19.14,19.25,19.3,19.09,19.42,19.33,18.96,19.29,19.29,19.15,19.34,19.48,20.39,19.55,19.21,19.84,19.53,19.48,19.49,19.78,19.7,19.69,19.58,20.07,19.69,19.6,19.94,20.15,19.58,19.54,19.83,19.77,19.96,21.28],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"] ...

# %% [markdown]
# Data source = "https://data.gov.in/catalog/all-india-seasonal-and-annual-minmax-temperature-series"

# %% [markdown]
# The average temperature of India has increased from 1990 to 2016 by 2 degree Celsius. This trend of increasing annual temperature for India is in line with the increasing global surface temperatures. The major change took place in 1980 as the urbanization came to it's peak after the independance of India in 1950.

# %% [markdown]
# ###Let's analyse even further

# %%
India_df = pd.read_csv("/content/drive/MyDrive/Data viz project/Weather Data in India from 1901 to 2017.csv", index_col=0)

India_df.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  17.99  19.43  23.49  26.41  28.28  28.60  27.49  26.98  26.26  25.08
# 1  1902  19.00  20.39  24.10  26.54  28.68  28.44  27.29  27.05  25.95  24.37
# 2  1903  18.32  19.79  22.46  26.03  27.93  28.41  28.04  26.63  26.34  24.57
# 3  1904  17.77  19.39  22.95  26.73  27.83  27.85  26.84  26.73  25.84  24.36
# 4  1905  17.40  17.79  21.78  24.84  28.32  28.69  27.67  27.47  26.29  26.16
#
#      NOV    DEC
# 0  21.73  18.95
# 1  21.33  18.78
# 2  20.96  18.29
# 3  21.07  18.84
# 4  22.07  18.71

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

India_df['Yearly Mean'] = India_df.iloc[:,1:].mean(axis=1) 
fig = go.Figure(data=[
    go.Scatter(name='Yearly Tempratures' , x=India_df['YEAR'], y=India_df['Yearly Mean'], mode='lines'),
    go.Scatter(name='Yearly Tempratures' , x=India_df['YEAR'], y=India_df['Yearly Mean'], mode='markers')
])
fig.update_layout(title='Yearly Mean Temprature :',
                 xaxis_title='Time', yaxis_title='Temprature (°C)')
fig.show()

fig = px.scatter(India_df,x = 'YEAR', y = 'Yearly Mean', trendline = 'lowess')
fig.update_layout(title='Trendline Over The Years :',
                 xaxis_title='Time', yaxis_title='Temprature(°C)')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9db20678-6953-46c9-bbf6-6309311dad7d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9db20678-6953-46c9-bbf6-6309311dad7d")) {                    Plotly.newPlot(                        "9db20678-6953-46c9-bbf6-6309311dad7d",                        [{"mode":"lines","name":"Yearly Tempratures","x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"y":[24.224166666666665,24.326666666666664,23.980833333333333,23.849999999999998,23.9325,24.099999999999998,24.007499999999997,23.95,23.778333333333336,23.760833333333338,23.954166666666666,24.105833333333337,23.882500000000004,24.034166666666668,24.288333333333338,24.075000000000003,23.57083333333333,23.825833333333332,24.012500000000003,23.90833333333333,24.584166666666672,24.22416666666666,24.0475,24.140833333333337,23.95,24.055000000000003,23.94,24.290000000000003,24.08083333333333,23.930833333333336,24.435833333333335,24.2075,23.915833333333335,24.131666666666664,24.0625,24.124166666666667,23.980833333333333,23.98333333333333,24.010833333333334,24.045833333333338,24.659166666666668,24.2925,23.94916666666666,24.040833333333335,23.915833333333328,24.418333333333333,24.358333333333334,24.103333333333335,24.08583333333333,23.735,24.246666666666666,24.344166666666666,24.580000000000002,24.126666666666665,23.967499999999998,23.950833333333332,23.967500000000005,24.621666666666666,24.29416666666667,24.28583333333333,24.002499999999998,24.044166666666666,24.14833333333333,24.094166666666666,24.065,24.355,24.110833333333332,23.94083333333333,24.457500000000007,24.265,23.909166666666664,24.101666666666663,24.40583333333333,24.000833333333333,23.74416666666667,24.067500000000006,24.349999999999998,24.238333333333333,24.566666666666666,24.5475,24.265833333333333,24.153333333333332,24.11916666666667,24.254166666666663,24.444166666666664,24.205833333333334,24.570833333333336,24.421666666666667,24.03333333333333,24.218333333333334,24.280833333333334,24.147499999999997,24.42916666666667,24.464166666666667,25.28,24.657500000000002,24.254166666666666,24.694999999999997,24.66083333333333,24.576666666666668,24.81416666666667,25.03166666666667,24.7,24.799166666666668,24.576666666666668,25.0125,24.7675,24.6125,25.1125,25.189166666666665,24.710833333333326,24.678333333333338,24.819999999999997,24.732499999999998,24.912499999999998,26.454166666666662,26.291666666666668],"type":"scatter"},{"mode":"markers","name":"Yearly Tempratures","x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"y":[24.224166666666665,24.326666666666664,23.980833333333333,23.849999999999998,23.9325,24.099999999999998,24.007499999999997,23.95,23.778333333333336,23.760833333333338,23.954 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="23b01930-4cc5-418f-9014-8a904e1bce8a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23b01930-4cc5-418f-9014-8a904e1bce8a")) {                    Plotly.newPlot(                        "23b01930-4cc5-418f-9014-8a904e1bce8a",                        [{"hovertemplate":"YEAR=%{x}<br>Yearly Mean=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[24.224166666666665,24.326666666666664,23.980833333333333,23.849999999999998,23.9325,24.099999999999998,24.007499999999997,23.95,23.778333333333336,23.760833333333338,23.954166666666666,24.105833333333337,23.882500000000004,24.034166666666668,24.288333333333338,24.075000000000003,23.57083333333333,23.825833333333332,24.012500000000003,23.90833333333333,24.584166666666672,24.22416666666666,24.0475,24.140833333333337,23.95,24.055000000000003,23.94,24.290000000000003,24.08083333333333,23.930833333333336,24.435833333333335,24.2075,23.915833333333335,24.131666666666664,24.0625,24.124166666666667,23.980833333333333,23.98333333333333,24.010833333333334,24.045833333333338,24.659166666666668,24.2925,23.94916666666666,24.040833333333335,23.915833333333328,24.418333333333333,24.358333333333334,24.103333333333335,24.08583333333333,23.735,24.246666666666666,24.344166666666666,24.580000000000002,24.126666666666665,23.967499999999998,23.950833333333332,23.967500000000005,24.621666666666666,24.29416666666667,24.28583333333333,24.002499999999998,24.044166666666666,24.14833333333333,24.094166666666666,24.065,24.355,24.110833333333332,23.94083333333333,24.457500000000007,24.265,23.909166666666664,24.101666666666663,24.40583333333333,24.000833333333333,23.74416666666667,24.067500000000006,24.349999999999998,24.238333333333333,24.566666666666666,24.5475,24.265833333333333,24.153333333333332,24.11916666666667,24.254166666666663,24.444166666666664,24.205833333333334,24.570833333333336,24.421666666666667,24.03333333333333,24.218333333333334,24.280833333333334,24.147499999999997,24.42916666666667,24.464166666666667,25.28,24.657500000000002,24.254166666666666,24.694999999999997,24.66083333333333,24.576666666666668,24.81416666666667,25.03166666666667,24.7,24.799166666666668,24.576666666666668,25.0125,24.7675,24.6125,25.1125,25.189166666666665,24.710833333333326,24.678333333333338,24.819999999999997,24.732499999999998,24.912499999999998,26.454166666666662,26.291666666666668],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>LOWESS trendline</b><br><br>YEAR=%{x}<br>Yearly Mean=%{y} <b>(trend)</b><extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":[1901,1902,1903,1904,1905,1906,1907,1908,1909,1910,1911,1912,1913,1914,1915,1916,1917,1918,1919,1920,1921,1922,1923,1924,1925,1926,1927,1928,1929,1930,1931,1932,1933,1934,1935,1936,1937,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984 ...

# %% [markdown]
# Data source = "https://data.gov.in/catalog/all-india-seasonal-and-annual-minmax-temperature-series"

# %% [markdown]
# In this graphs we can clearly see that after 1995 and 2015 there is a huge change in the temperature. We are using Locally weighted scatterplot smoothing, also known as LOWESS (Locally Weighted Scatterplot Smoothing), is a common method used in regression analysis that draws a smooth line through a timeplot or scatter plot to help you detect relationships between variables and predict trends.

# %% [markdown]
# ##Visualizing according to change in the temperature according to the states

# %%
state_df = pd.read_csv("/content/drive/MyDrive/Data viz project/GlobalLandTemperaturesByState.csv")

# %%
state_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty State Country
# 0  1855-05-01              25.544                          1.171  Acre  Brazil
# 1  1855-06-01              24.228                          1.103  Acre  Brazil
# 2  1855-07-01              24.371                          1.044  Acre  Brazil
# 3  1855-08-01              25.427                          1.073  Acre  Brazil
# 4  1855-09-01              25.675                          1.014  Acre  Brazil

# %%
state_df.dtypes
# Out:
# dt                                object
# AverageTemperature               float64
# AverageTemperatureUncertainty    float64
# State                             object
# Country                           object
# dtype: object

# %%
state_df.shape
# Out:
# (645675, 5)

# %% [markdown]
# ###Cleaning the data

# %%
state_df.isnull().sum()
# Out:
# dt                                   0
# AverageTemperature               25648
# AverageTemperatureUncertainty    25648
# State                                0
# Country                              0
# dtype: int64

# %%
#drop NA values as our dataset is huge 
state_df.dropna(how ='any', axis =0)
# Out:
#                 dt  AverageTemperature  AverageTemperatureUncertainty  \
# 0       1855-05-01              25.544                          1.171
# 1       1855-06-01              24.228                          1.103
# 2       1855-07-01              24.371                          1.044
# 3       1855-08-01              25.427                          1.073
# 4       1855-09-01              25.675                          1.014
# ...            ...                 ...                            ...
# 645669  2013-04-01              15.710                          0.461
# 645670  2013-05-01              21.634                          0.578
# 645671  2013-06-01              24.679                          0.596
# 645672  2013-07-01              29.272                          1.340
# 645673  2013-08-01              29.202                          0.869
#
#            State Country
# 0           Acre  Brazil
# 1           Acre  Brazil
# 2           Acre  Brazil
# 3           Acre  Brazil
# 4           Acre  Brazil
# ...          ...     ...
# 645669  Zhejiang   China
# 645670  Zhejiang   China
# 645671  Zhejiang   China
# 645672  Zhejiang   China
# 645673  Zhejiang   China
#
# [620027 rows x 5 columns]

# %%
state_df.rename(columns={'dt':'Date'}, inplace = True)
state_df.drop(columns='AverageTemperatureUncertainty', inplace = True)
state_df.head()
# Out:
#          Date  AverageTemperature State Country
# 0  1855-05-01              25.544  Acre  Brazil
# 1  1855-06-01              24.228  Acre  Brazil
# 2  1855-07-01              24.371  Acre  Brazil
# 3  1855-08-01              25.427  Acre  Brazil
# 4  1855-09-01              25.675  Acre  Brazil

# %%
#changing the data type of date format
from datetime import datetime, timedelta
state_df['Date'] = pd.to_datetime(state_df['Date'])

# %%
state_df.dtypes
# Out:
# Date                  datetime64[ns]
# AverageTemperature           float64
# State                         object
# Country                       object
# dtype: object

# %% [markdown]
# ###Plotting interactive Tree map to check which state had the most average temperature

# %%
country_state_temp = state_df.groupby(by = ['Country','State']).mean().reset_index().sort_values('AverageTemperature',ascending=False).reset_index()
country_state_temp
country_state_temp["world"] = "world"
fig6 = px.treemap(country_state_temp.head(200), path=['world', 'Country','State'], values='AverageTemperature',
                  color='State',color_continuous_scale='RdBu')
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="86af8ec4-a648-4b23-8b74-a9de77fa3ffa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("86af8ec4-a648-4b23-8b74-a9de77fa3ffa")) {                    Plotly.newPlot(                        "86af8ec4-a648-4b23-8b74-a9de77fa3ffa",                        [{"branchvalues":"total","customdata":[["Arunachal Pradesh"],["Mississippi"],["Ingush"],["Chuvash"],["West Virginia"],["Anhui"],["Adygey"],["Alabama"],["Kansas"],["Kalmyk"],["Jilin"],["Kostroma"],["Goa"],["New Hampshire"],["Manipur"],["Dagestan"],["Virginia"],["Nei Mongol"],["Perm'"],["Colorado"],["Xinjiang Uygur"],["Punjab"],["Kentucky"],["Krasnodar"],["New York"],["Voronezh"],["Beijing"],["Jiangsu"],["Tianjin"],["Stavropol'"],["Orel"],["Nebraska"],["Chandigarh"],["Missouri"],["Andhra Pradesh"],["Maharashtra"],["California"],["Madhya Pradesh"],["Guangdong"],["Guangxi"],["Henan"],["Rhode Island"],["Idaho"],["Australian Capital Territory"],["Hainan"],["Haryana"],["Kaluga"],["Andaman And Nicobar"],["Connecticut"],["Dadra And Nagar Haveli"],["Florida"],["Nagaland"],["Wisconsin"],["Komi Permyak"],["Moskva"],["Kabardin Balkar"],["Ivanovo"],["Rajasthan"],["Mato Grosso"],["Massachusetts"],["Novgorod"],["New Mexico"],["Tocantins"],["Tver'"],["Chechnya"],["Karachay Cherkess"],["Illinois"],["South Carolina"],["Novosibirsk"],["Pennsylvania"],["Montana"],["Shandong"],["Lipetsk"],["Ningxia Hui"],["Western Australia"],["Bashkortostan"],["Kurgan"],["Amazonas"],["Washington"],["Wyoming"],["Victoria"],["Minnesota"],["West Bengal"],["Puducherry"],["Tula"],["Ohio"],["Samara"],["Hebei"],["Bryansk"],["Arizona"],["Shanghai"],["Gujarat"],["Vermont"],["Louisiana"],["Northern Territory"],["Belgorod"],["Daman And Diu"],["Delaware"],["Penza"],["Georgia (State)"],["Saratov"],["Hunan"],["Liaoning"],["District Of Columbia"],["Rio Grande Do Sul"],["Tambov"],["South Australia"],["South Dakota"],["Guizhou"],["Nevada"],["Udmurt"],["Mizoram"],["Tamil Nadu"],["Pskov"],["Meghalaya"],["Maine"],["Indiana"],["Oklahoma"],["Nova Scotia"],["Tripura"],["Karelia"],["Sichuan"],["Orissa"],["Chhattisgarh"],["Prince Edward Island"],["Tatarstan"],["Zhejiang"],["Minas Gerais"],["Kaliningrad"],["North Carolina"],["Roraima"],["Ul'Yanovsk"],["Arkansas"],["Moscow City"],["Smolensk"],["Yunnan"],["British Columbia"],["Vologda"],["Ryazan'"],["Sergipe"],["Acre"],["Delhi"],["Distrito Federal"],["Bahia"],["New Brunswick"],["Gansu"],["Alagoas"],["Heilongjiang"],["Astrakhan'"],["Nizhegorod"],["Sikkim"],["Tasmania"],["Himachal Pradesh"],["Rostov"],["Bihar"],["Michigan"],["Kursk"],["Jharkhand"],["New Jersey"],["North Dakota"],["Utah"],["Shaanxi"],["Hawaii"],["Iowa"],["Oregon"],["Mordovia"],["Yaroslavl'"],["Santa Catarina"],["Altay"],["Mato Grosso Do Sul"],["Uttaranchal"],["Kerala"],["Hubei"],["Mariy El"],["Assam"],["Chongqing"],["Shanxi"],["Tennessee"],["Volgograd"],["Texas"],["New South Wales"],["City Of St. Petersburg"],["Karnataka"],["Queensland"],["Kirov"],["Leningrad"],["Sverdlovsk"],["Orenburg"],["Vladimir"],["Pernambuco"],["North Ossetia"],["Chelyabinsk"],["Maryland"],["Fujian"],["Primor'Ye"],["Rio Grande Do Norte"],["Rio De Janeiro"],["Uttar Pradesh"],["Jiangxi"],["Jammu And Kashmir"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"],["(?)"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>AverageTemperature=%{value}<br>parent=%{parent}<br>id=%{id}<br>State=%{customdata[0]}<extra></extra>","ids":["world/India/Arunachal Pradesh","world/United States/Mississippi","world/Russia/Ingush","world/Russia/Chuvash","world/United States/West Virginia","world/China/Anhui","world/Russia/Adygey","world/United States/Alabama","world/United States/Kansas","world/Russia/Kalmyk","world/China/Jilin","world/Russia/Kostroma","world/Ind ...

# %% [markdown]
# Here in this interactive treemap we can see the states which has most average temprature and gives a indetail view on it.

# %%
#droping the rest of the countries data 
df_filtered = state_df[state_df['Country'] == 'India']
 
# Print the new dataframe
print(df_filtered.head(15))
# Out:
#             Date  AverageTemperature                State Country
# 24709 1796-01-01              26.534  Andaman And Nicobar   India
# 24710 1796-02-01              26.294  Andaman And Nicobar   India
# 24711 1796-03-01              26.180  Andaman And Nicobar   India
# 24712 1796-04-01              27.942  Andaman And Nicobar   India
# 24713 1796-05-01              28.651  Andaman And Nicobar   India
# 24714 1796-06-01              28.307  Andaman And Nicobar   India
# 24715 1796-07-01              27.482  Andaman And Nicobar   India
# 24716 1796-08-01              28.025  Andaman And Nicobar   India
# 24717 1796-09-01              27.185  Andaman And Nicobar   India
# 24718 1796-10-01              26.808  Andaman And Nicobar   India
# 24719 1796-11-01              26.646  Andaman And Nicobar   India
# 24720 1796-12-01              24.796  Andaman And Nicobar   India
# 24721 1797-01-01                 NaN  Andaman And Nicobar   India
# 24722 1797-02-01                 NaN  Andaman And Nicobar   India
# 24723 1797-03-01              26.717  Andaman And Nicobar   India

# %%
df_filtered.AverageTemperature.isnull().sum()
# Out:
# 5044

# %%
df_filtered.dropna(inplace = True, axis = 0)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_filtered.head(15)
# Out:
#             Date  AverageTemperature                State Country
# 24709 1796-01-01              26.534  Andaman And Nicobar   India
# 24710 1796-02-01              26.294  Andaman And Nicobar   India
# 24711 1796-03-01              26.180  Andaman And Nicobar   India
# 24712 1796-04-01              27.942  Andaman And Nicobar   India
# 24713 1796-05-01              28.651  Andaman And Nicobar   India
# 24714 1796-06-01              28.307  Andaman And Nicobar   India
# 24715 1796-07-01              27.482  Andaman And Nicobar   India
# 24716 1796-08-01              28.025  Andaman And Nicobar   India
# 24717 1796-09-01              27.185  Andaman And Nicobar   India
# 24718 1796-10-01              26.808  Andaman And Nicobar   India
# 24719 1796-11-01              26.646  Andaman And Nicobar   India
# 24720 1796-12-01              24.796  Andaman And Nicobar   India
# 24723 1797-03-01              26.717  Andaman And Nicobar   India
# 24724 1797-04-01              27.111  Andaman And Nicobar   India
# 24725 1797-05-01              27.856  Andaman And Nicobar   India

# %%
#adding lat and long
lat = pd.read_csv("/content/drive/MyDrive/Data viz project/poptable.csv")
lat.head()
# Out:
#                  State   latitude  longitude
# 0  Andaman And Nicobar  11.667026  92.735983
# 1       Andhra Pradesh  14.750429  78.570026
# 2    Arunachal Pradesh  27.100399  93.616601
# 3                Assam  26.749981  94.216667
# 4                Bihar  25.785414  87.479973

# %%
df_filtered['State'].unique()
# Out:
# array(['Andaman And Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra And Nagar Haveli', 'Daman And Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu And Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttaranchal',
#        'West Bengal'], dtype=object)

# %%
lat['State'].unique()
# Out:
# array(['Andaman And Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra And Nagar Haveli', 'Daman And Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu And Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala ', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'Orissa', 'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim',
#        'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttaranchal',
#        'West Bengal'], dtype=object)

# %%
Final_df = pd.merge(df_filtered, lat)

# %%
Final_df.tail(15)
# Out:
#             Date  AverageTemperature        State Country  latitude  longitude
# 79121 2012-06-01              30.833  West Bengal   India  22.58039  88.329947
# 79122 2012-07-01              28.667  West Bengal   India  22.58039  88.329947
# 79123 2012-08-01              28.842  West Bengal   India  22.58039  88.329947
# 79124 2012-09-01              28.496  West Bengal   India  22.58039  88.329947
# 79125 2012-10-01              26.182  West Bengal   India  22.58039  88.329947
# 79126 2012-11-01              22.359  West Bengal   India  22.58039  88.329947
# 79127 2012-12-01              18.879  West Bengal   India  22.58039  88.329947
# 79128 2013-01-01              16.974  West Bengal   India  22.58039  88.329947
# 79129 2013-02-01              20.974  West Bengal   India  22.58039  88.329947
# 79130 2013-03-01              26.121  West Bengal   India  22.58039  88.329947
# 79131 2013-04-01              28.707  West Bengal   India  22.58039  88.329947
# 79132 2013-05-01              29.694  West Bengal   India  22.58039  88.329947
# 79133 2013-06-01              29.628  West Bengal   India  22.58039  88.329947
# 79134 2013-07-01              29.115  West Bengal   India  22.58039  88.329947
# 79135 2013-08-01              28.686  West Bengal   India  22.58039  88.329947

# %% [markdown]
# I am saving this file to work on this in Tableau

# %%
Final_df.to_csv('Final_df.csv')

# %%
# !pip install kora
from kora.drive import upload_public
url = upload_public('/content/drive/MyDrive/Data viz project/Temperature change.mp4')
# then display it
from IPython.display import HTML
HTML(f"""<video src={url} width=500 controls/>""")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kora
#   Downloading kora-0.9.20-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 3.4 MB/s
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from kora) (7.9.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.8/dist-packages (from kora) (1.5.27)
# Requirement already satisfied: pip in /usr/local/lib/python3.8/dist-packages (from fastcore->kora) (21.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from fastcore->kora) (21.3)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (2.0.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (0.7.5)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (2.6.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (57.4.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (4.8.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 15.6 MB/s
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->kora) (5.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->kora) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->kora) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->kora) (0.2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->fastcore->kora) (3.0.9)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->kora) (0.7.0)
# Installing collected packages: jedi, kora
# Successfully installed jedi-0.18.2 kora-0.9.20
# <video src=https://drive.google.com/uc?id=1zdlSvO_xFKQ2Eau7OwAIC9mPJ38Ofn6w width=500 controls/>

# %% [markdown]
# To check the work click the link -  https://public.tableau.com/views/TempChangeDataviz/Sheet1?:language=en-US&:display_count=n&:origin=viz_share_link

# %% [markdown]
# In Madhya Pradesh, the median average temperature in 1950 was 25.77°C, Rajasthan 27.35°C, and Uttaranchal 15.44°C. But in 2013, the temperature changed drastically. The median average temperature of Madhya Pradesh, Rajasthan, and Uttaranchal became 26.93°C, 29.64°C, and 18.75°C, respectively.

# %% [markdown]
# We might think 2°C is not more, but it is more than enough to cause glaciers to melt and can cause heatwaves.  Without concomitant increases in precipitation, heatwaves can lead to water shortages and increased stress for plants, particularly in arid regions.
#
# Check this article by NASA - https://climate.nasa.gov/news/2865/a-degree-of-concern-why-global-temperatures-matter/

# %% [markdown]
# ##Let's see the reasons behind the increase in the temperature

# %% [markdown]
# We Dwell in a Greenhouse gas. Energy from the Sun is essential to life on Earth. A majority of the light that reaches the Earth's atmosphere is absorbed by the atmosphere and clouds as it travels to the surface, where it is subsequently reflected upward as infrared heat. The greenhouse gases then absorb around 90% of this heat and reflect it back toward the surface.

# %% [markdown]
# We have data about the greenhouse gas emission. Let's find out if the we can related the change in the gas with the change in the temperature

# %%
gas_df = pd.read_csv("/content/drive/MyDrive/Data viz project/ghg-emissions.csv", index_col=0)

# %%
gas_df.head()
# Out:
#          CH4     CO2     N2O
# Year
# 1990  511.25  342.41  147.25
# 1991  516.81  386.06  151.40
# 1992  518.28  405.13  155.55
# 1993  522.27  430.19  159.09
# 1994  525.93  464.74  164.80

# %%
fig = px.area(gas_df,
              title=" Greenhouse gas emission in India from year 1990-2019",
              labels = {
                  'value' : 'Greenhouse gas emission (measured in MtCO2e)'
              })
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f6bcdcbf-992c-4262-9cfe-57f3c264017f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6bcdcbf-992c-4262-9cfe-57f3c264017f")) {                    Plotly.newPlot(                        "f6bcdcbf-992c-4262-9cfe-57f3c264017f",                        [{"hovertemplate":"variable=CH4<br>Year=%{x}<br>Greenhouse gas emission (measured in MtCO2e)=%{y}<extra></extra>","legendgroup":"CH4","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"CH4","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[511.25,516.81,518.28,522.27,525.93,535.25,543.92,551.86,560.55,569.23,573.0,574.73,567.32,575.75,583.04,594.88,603.22,616.14,622.34,622.39,627.11,631.48,632.59,634.57,637.04,640.43,645.12,650.82,657.15,658.09],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=CO2<br>Year=%{x}<br>Greenhouse gas emission (measured in MtCO2e)=%{y}<extra></extra>","legendgroup":"CO2","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"CO2","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[342.41,386.06,405.13,430.19,464.74,516.73,552.95,598.17,615.17,680.23,716.76,958.52,990.43,1016.75,1090.64,1141.44,1220.18,1341.71,1429.35,1569.87,1664.96,1691.92,1844.61,1907.6,2082.27,2093.18,2160.98,2286.13,2417.66,2422.03],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=N2O<br>Year=%{x}<br>Greenhouse gas emission (measured in MtCO2e)=%{y}<extra></extra>","legendgroup":"N2O","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"N2O","orientation":"v","showlegend":true,"stackgroup":"1","x":[1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019],"xaxis":"x","y":[147.25,151.4,155.55,159.09,164.8,168.31,171.67,176.81,180.72,184.19,180.54,184.86,178.71,187.28,194.89,203.35,212.94,223.65,227.16,235.78,243.22,249.07,250.14,248.33,250.58,254.05,253.4,259.55,265.59,261.74],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#b ...

# %% [markdown]
# datasource = https://www.climatewatchdata.org/ghg-emissions

# %% [markdown]
# Over the past 30 years, we can that emissions of CO2, methane, and n20 have been rising. Due to rising industrialization, globalization, and the combustion of fossil fuels, in India the carbon dioxide makes up the bulk of greenhouse gas emissions. Studies have revealed that nitrous oxide and methane emissions are far more destructive in terms of their influence on climate change, even though they are smaller in comparison.
#
# Effect of greenhouse gas: https://www.epa.gov/climate-indicators/greenhouse-gases#:~:text=An%20increase%20in%20the%20atmospheric,atmosphere%20increased%20by%2045%20percent.

# %% [markdown]
# ## This is all about India at last let us see how the GDP of countries is related to the carbon emission.

# %%
#reading the data
gdpcm_df = pd.read_csv("/content/drive/MyDrive/Data viz project/GDP vs Carbon Dioxide emissions (2018)_Full Data_data.csv")

# %%
gdpcm_df.head()
# Out:
#        Continent Country Name  CO2 emissions           GDP  Population
# 0           Asia  Afghanistan           7.59   18400000000    37171922
# 1         Europe      Albania           5.32   15100000000     2866376
# 2         Africa      Algeria         151.87  175000000000    42228415
# 3         Africa       Angola          62.93  101000000000    30809787
# 4  South America    Argentina         207.11  518000000000    44494502

# %%
import plotly.express as px
fig = px.scatter(gdpcm_df, x="GDP", y="CO2 emissions", color="Continent",
                 size='Population', hover_data=['Country Name'], 
                 labels = {
                     'GDP': 'GDP (measure in USD)',
                     'CO2 emissions': 'CO2 emissions(measures in MTCO2e)'
                 },
                 log_x =True, log_y = True,
                 size_max=60)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="48022273-0552-4769-a4f0-1024d61cbecc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48022273-0552-4769-a4f0-1024d61cbecc")) {                    Plotly.newPlot(                        "48022273-0552-4769-a4f0-1024d61cbecc",                        [{"customdata":[["Afghanistan"],["Bahrain"],["Bangladesh"],["Brunei Darussalam"],["Cambodia"],["China"],["India"],["Indonesia"],["Iran, Islamic Rep."],["Iraq"],["Israel"],["Japan"],["Jordan"],["Kazakhstan"],["Kuwait"],["Kyrgyz Republic"],["Lao PDR"],["Lebanon"],["Malaysia"],["Myanmar"],["Nepal"],["Oman"],["Pakistan"],["Philippines"],["Qatar"],["Russian Federation"],["Saudi Arabia"],["Singapore"],["Sri Lanka"],["Tajikistan"],["Thailand"],["Turkey"],["Turkmenistan"],["United Arab Emirates"],["Uzbekistan"],["Vietnam"],["Yemen, Rep."]],"hovertemplate":"Continent=Asia<br>GDP (measure in USD)=%{x}<br>CO2 emissions(measures in MTCO2e)=%{y}<br>Population=%{marker.size}<br>Country Name=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#636efa","size":[37171922,1569440,161000000,428960,16249795,1390000000,1350000000,268000000,81800204,38433604,8882800,127000000,9965322,18276452,4137314,6322800,7061498,6859408,31528033,53708318,28095712,4829476,212000000,107000000,2781682,144000000,33702757,5638676,21670000,9100847,69428454,82340090,5850902,9630966,32956100,95545959,28498683],"sizemode":"area","sizeref":386111.1111111111,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[18400000000,37700000000,274000000000,13600000000,24600000000,13900000000000,2700000000000,1040000000000,294000000000,212000000000,370000000000,5040000000000,42900000000,179000000000,138000000000,8270000000,18000000000,55000000000,359000000000,68700000000,33100000000,79800000000,315000000000,347000000000,183000000000,1660000000000,787000000000,376000000000,88000000000,7770000000,507000000000,778000000000,40800000000,422000000000,50400000000,245000000000,23500000000],"xaxis":"x","y":[7.59,30.75,104.5,7.47,40.16,9663.36,2400.25,1269.55,629.35,188.64,62.05,1074.08,24.7,217.46,89.45,7.73,27.46,27.63,319.59,136.92,14.97,73.39,215.37,144.7,90.17,1049.05,514.6,47.39,23.54,7.2,270.9,384.32,71.73,200.3,108.72,245.36,9.31],"yaxis":"y","type":"scatter"},{"customdata":[["Albania"],["Armenia"],["Austria"],["Azerbaijan"],["Belarus"],["Belgium"],["Bosnia and Herzegovina"],["Bulgaria"],["Croatia"],["Cyprus"],["Czech Republic"],["Denmark"],["Estonia"],["Finland"],["France"],["Georgia"],["Germany"],["Greece"],["Hungary"],["Iceland"],["Ireland"],["Italy"],["Latvia"],["Lithuania"],["Luxembourg"],["Moldova"],["Mongolia"],["Montenegro"],["Netherlands"],["Norway"],["Poland"],["Portugal"],["Romania"],["Serbia"],["Slovak Republic"],["Slovenia"],["Spain"],["Sweden"],["Switzerland"],["Ukraine"],["United Kingdom"]],"hovertemplate":"Continent=Europe<br>GDP (measure in USD)=%{x}<br>CO2 emissions(measures in MTCO2e)=%{y}<br>Population=%{marker.size}<br>Country Name=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#EF553B","size":[2866376,2951741,8840521,9939771,9483499,11427054,3323929,7025037,4087843,1189262,10629928,5793636,1321977,5515525,67101930,3726549,82905782,10732882,9775564,352721,4867316,60421760,1927174,2801543,607950,2708214,3170214,622227,17231624,5311916,37974750,10283822,19473970,6982604,5446771,2073894,46797754,10175214,8514329,44622518,66460344],"sizemode":"area","sizeref":386111.1111111111,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[15100000000,12500000000,455000000000,47100000000,60000000000,543000000000,20200000000,66200000000,61400000000,25300000000,249000000000,357000000000,30500000000,276000000000,2790000000 ...

# %% [markdown]
# Graph showing the logarithmic relationship between GDP and carbon dioxide emissions for various nations in 2018. Metric tons of carbon dioxide equivalent, or MTCO2e, is used to measure carbon dioxide emissions. USD are used to measure GDP.
#
# Data source:
# https://data.worldbank.org/indicator/NY.GDP.MKTP.CD
#
# https://www.climatewatchdata.org/ghg-emissions?breakBy=countries&end_year=2018&gases=co2&sectors=transportation&start_year=1990

# %% [markdown]
# The wealthier nations, or those with a greater Gross Domestic Product (GDP), contribute more to carbon dioxide emissions, as shown by the positive connection between GDP and carbon dioxide emissions for 2018.The correlation between the emissions and a nation's population serves as further evidence that greenhouse gas emissions are indeed caused by human activity. Also evident is how little the African countries contribute to global carbon dioxide emissions. Because of this, not all nations have the same share of the blame for greenhouse gas emissions. The Asian nations with a developing industrial sector and a shift toward industrialization and globalization are more responsible for the increase in carbon dioxide emissions. Many European nations with lower populations contribute significantly or nearly as much as those with bigger populations and comparable GDPs. However, the lack of emphasis on per-capita emissions in the climate agreements discourages developing nations from ratifying the treaty.

# %%
import plotly.express as px
fig = px.scatter(gdpcm_df, x="GDP", y="CO2 emissions", color="Continent",
                 size='Population', hover_data=['Country Name'], 
                 labels = {
                     'GDP': 'GDP (measure in USD)',
                     'CO2 emissions': 'CO2 emissions(measures in MTCO2e)'
                 },
                 #log_x =True, log_y = True,
                 #size_max=60
                 )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="09793724-ebd7-4318-ab9b-09dda3233998" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09793724-ebd7-4318-ab9b-09dda3233998")) {                    Plotly.newPlot(                        "09793724-ebd7-4318-ab9b-09dda3233998",                        [{"customdata":[["Afghanistan"],["Bahrain"],["Bangladesh"],["Brunei Darussalam"],["Cambodia"],["China"],["India"],["Indonesia"],["Iran, Islamic Rep."],["Iraq"],["Israel"],["Japan"],["Jordan"],["Kazakhstan"],["Kuwait"],["Kyrgyz Republic"],["Lao PDR"],["Lebanon"],["Malaysia"],["Myanmar"],["Nepal"],["Oman"],["Pakistan"],["Philippines"],["Qatar"],["Russian Federation"],["Saudi Arabia"],["Singapore"],["Sri Lanka"],["Tajikistan"],["Thailand"],["Turkey"],["Turkmenistan"],["United Arab Emirates"],["Uzbekistan"],["Vietnam"],["Yemen, Rep."]],"hovertemplate":"Continent=Asia<br>GDP (measure in USD)=%{x}<br>CO2 emissions(measures in MTCO2e)=%{y}<br>Population=%{marker.size}<br>Country Name=%{customdata[0]}<extra></extra>","legendgroup":"Asia","marker":{"color":"#636efa","size":[37171922,1569440,161000000,428960,16249795,1390000000,1350000000,268000000,81800204,38433604,8882800,127000000,9965322,18276452,4137314,6322800,7061498,6859408,31528033,53708318,28095712,4829476,212000000,107000000,2781682,144000000,33702757,5638676,21670000,9100847,69428454,82340090,5850902,9630966,32956100,95545959,28498683],"sizemode":"area","sizeref":3475000.0,"symbol":"circle"},"mode":"markers","name":"Asia","orientation":"v","showlegend":true,"x":[18400000000,37700000000,274000000000,13600000000,24600000000,13900000000000,2700000000000,1040000000000,294000000000,212000000000,370000000000,5040000000000,42900000000,179000000000,138000000000,8270000000,18000000000,55000000000,359000000000,68700000000,33100000000,79800000000,315000000000,347000000000,183000000000,1660000000000,787000000000,376000000000,88000000000,7770000000,507000000000,778000000000,40800000000,422000000000,50400000000,245000000000,23500000000],"xaxis":"x","y":[7.59,30.75,104.5,7.47,40.16,9663.36,2400.25,1269.55,629.35,188.64,62.05,1074.08,24.7,217.46,89.45,7.73,27.46,27.63,319.59,136.92,14.97,73.39,215.37,144.7,90.17,1049.05,514.6,47.39,23.54,7.2,270.9,384.32,71.73,200.3,108.72,245.36,9.31],"yaxis":"y","type":"scatter"},{"customdata":[["Albania"],["Armenia"],["Austria"],["Azerbaijan"],["Belarus"],["Belgium"],["Bosnia and Herzegovina"],["Bulgaria"],["Croatia"],["Cyprus"],["Czech Republic"],["Denmark"],["Estonia"],["Finland"],["France"],["Georgia"],["Germany"],["Greece"],["Hungary"],["Iceland"],["Ireland"],["Italy"],["Latvia"],["Lithuania"],["Luxembourg"],["Moldova"],["Mongolia"],["Montenegro"],["Netherlands"],["Norway"],["Poland"],["Portugal"],["Romania"],["Serbia"],["Slovak Republic"],["Slovenia"],["Spain"],["Sweden"],["Switzerland"],["Ukraine"],["United Kingdom"]],"hovertemplate":"Continent=Europe<br>GDP (measure in USD)=%{x}<br>CO2 emissions(measures in MTCO2e)=%{y}<br>Population=%{marker.size}<br>Country Name=%{customdata[0]}<extra></extra>","legendgroup":"Europe","marker":{"color":"#EF553B","size":[2866376,2951741,8840521,9939771,9483499,11427054,3323929,7025037,4087843,1189262,10629928,5793636,1321977,5515525,67101930,3726549,82905782,10732882,9775564,352721,4867316,60421760,1927174,2801543,607950,2708214,3170214,622227,17231624,5311916,37974750,10283822,19473970,6982604,5446771,2073894,46797754,10175214,8514329,44622518,66460344],"sizemode":"area","sizeref":3475000.0,"symbol":"circle"},"mode":"markers","name":"Europe","orientation":"v","showlegend":true,"x":[15100000000,12500000000,455000000000,47100000000,60000000000,543000000000,20200000000,66200000000,61400000000,25300000000,249000000000,357000000000,30500000000,276000000000,2790000000000,17600000000, ...
